# %% [markdown]
# # Generalized Linear Models
#
# Going to be honest here: Main thing about GLMs just the machinery you need to go through. Read my article [here](https://justanotherbyte.github.io/publications.html?slug=glms).
